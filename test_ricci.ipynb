# %% [markdown]
# # They all check out
#
# Here I am trying to verify if the Ricci tensors that I compute agree with the ones obtained from formulas from Kelly Stelle.

# %% [markdown]
# In $D$ dimensions, for Einstein-Hilbert action coupled to n-forms
# \begin{equation}
# S = \int d^D x \sqrt{-g}\left[R - \sum_n\frac{1}{2}\frac{1}{n!}F_n^2\right]
# \end{equation}
#
# The Einstein equation is
#
# \begin{equation}
# R_{MN}
# = S_{MN}
# = \sum_n \frac{1}{2(n-1)!}
# \left[
# (F_n)_{M...}(F_n)_N{}^{...}-\frac{n-1}{n(d+\tilde{d})}(F_n)^2g_{MN}
# \right]
# \end{equation}

# %% [markdown]
# For a brane-like solution
# \begin{equation}
# ds_{D}^2 = e^{2A(r)}ds_{1,d-1}^2 + e^{2B(r)}ds_{\tilde{d} +2}^2,\quad
# D=d+\tilde d+2
# \end{equation}

# %% [markdown]
# The corresponding Ricci tensors are (according to Kelly hep-th/9803116 [hep-th])
# \begin{equation}
# R_{\mu\nu} = -\eta_{\mu\nu} \mathcal A
# \end{equation}
#
# \begin{equation}
# \mathcal A =H^{a-b}\left[ A^{\prime\prime}+d(A')^2+\tilde d A'B'+\frac{\tilde d+1}{r}A'\right]
# \end{equation}
#
# \begin{equation}
# R_{mn} = -\delta_{mn}\mathcal B - \frac{y^m y^n}{r^2} \mathcal C
# \end{equation}
#
# \begin{equation}
# \mathcal B = B^{\prime\prime}+dA'B'+\tilde d(B')^2 + \frac{2\tilde d+1}{r}B' + \frac{d}{r}A'
# \end{equation}
#
# \begin{equation}
# \mathcal C = \tilde d B^{\prime\prime} + d A^{\prime\prime}-2d A'B' + d(A')^2-\tilde d(B')^2 - \frac{1}{r}(\tilde d B'+d A')
# \end{equation}

# %% [markdown]
# # Computing Ricci using Kelly's formula

# %%
import sympy as sp
sp.init_printing(use_latex='mathjax')   # pretty LaTeX in Jupyter

# symbols & functions
r = sp.symbols('r', positive=True)
a, b = sp.symbols('a b', real=True)   # constants
d  = sp.Symbol('d', real=True)
td = sp.Symbol(r'\tilde{d}', real=True)   # displays as \tilde d
H = sp.Function('H')(r)

# %% [markdown]
# rewrite $e^{2A} = H^a$, $e^{2B}=H^b$

# %%
A = (a/2)*sp.log(H)
B = (b/2)*sp.log(H)

# derivatives
Apr  = sp.diff(A, r)
Appr = sp.diff(A, r, 2)
Bpr  = sp.diff(B, r)
Bppr = sp.diff(B, r, 2)

# %%
Acal = H**(a-b) * (Appr + d*Apr**2 + td*Apr*Bpr + (td + 1)*Apr/r)
Bcal = Bppr + d*Apr*Bpr + td*Bpr**2 + (2*td + 1)*Bpr/r + d*Apr/r
Ccal = td*Bppr + d*Appr - 2*d*Apr*Bpr + d*Apr**2 - td*Bpr**2 - (td*Bpr + d*Apr)/r

# %%
Acal
# Out:
# ⎛                                                 ⎛                      2⎞    ↪
# ⎜                                                 ⎜            ⎛d       ⎞ ⎟    ↪
# ⎜                                                 ⎜ 2          ⎜──(H(r))⎟ ⎟    ↪
# ⎜                        2                  2     ⎜d           ⎝dr      ⎠ ⎟    ↪
# ⎜              ⎛d       ⎞     2   ⎛d       ⎞    a⋅⎜───(H(r)) - ───────────⎟    ↪
# ⎜\tilde{d}⋅a⋅b⋅⎜──(H(r))⎟    a ⋅d⋅⎜──(H(r))⎟      ⎜  2            H(r)    ⎟    ↪
# ⎜              ⎝dr      ⎠         ⎝dr      ⎠      ⎝dr                     ⎠    ↪
# ⎜───────────────────────── + ──────────────── + ─────────────────────────── +  ↪
# ⎜            2                      2                     2⋅H(r)               ↪
# ⎝         4⋅H (r)                4⋅H (r)                                       ↪
#
# ↪                           ⎞
# ↪                           ⎟
# ↪                           ⎟
# ↪                           ⎟
# ↪                   d       ⎟
# ↪ a⋅(\tilde{d} + 1)⋅──(H(r))⎟
# ↪                   dr      ⎟  a - b
# ↪ ──────────────────────────⎟⋅H     (r)
# ↪          2⋅r⋅H(r)         ⎟
# ↪                           ⎠

# %%
# use the harmonic equation H'' + (td+1)/r * H' = 0  to eliminate H''
harmonic = {sp.diff(H, r, 2): -(td+1)/r * sp.diff(H, r)}

Acal_har_sub = sp.simplify(Acal.subs(harmonic))
Bcal_har_sub = sp.simplify(Bcal.subs(harmonic))
Ccal_har_sub = sp.simplify(Ccal.subs(harmonic))

# %%
Ccal_har_sub.factor()
# Out:
# ⎛             2                                            2   d               ↪
# ⎜- 2⋅\tilde{d} ⋅b⋅H(r) - 2⋅\tilde{d}⋅a⋅d⋅H(r) - \tilde{d}⋅b ⋅r⋅──(H(r)) - 2⋅\t ↪
# ⎝                                                              dr              ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪             d                                2     d                    d    ↪
# ↪ ilde{d}⋅b⋅r⋅──(H(r)) - 4⋅\tilde{d}⋅b⋅H(r) + a ⋅d⋅r⋅──(H(r)) - 2⋅a⋅b⋅d⋅r⋅──(H ↪
# ↪             dr                                     dr                   dr   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                       2                                                      ↪
# ↪                  4⋅r⋅H (r)                                                   ↪
#
# ↪                d                    ⎞ d
# ↪ (r)) - 2⋅a⋅d⋅r⋅──(H(r)) - 4⋅a⋅d⋅H(r)⎟⋅──(H(r))
# ↪                dr                   ⎠ dr
# ↪ ──────────────────────────────────────────────
# ↪
# ↪

# %%
d11_M2_subs = {d:3,td:6, a:-sp.Rational(2,3), b:sp.Rational(1,3)}
d11_M5_subs = {d:6,td:3, a:-sp.Rational(1,3), b:sp.Rational(2,3)}
d10_D3_subs = {d:4,td:4, a:-sp.Rational(1,2),b:sp.Rational(1,2)}

# %% [markdown]
# ## Using Kelly's formula for 11d M2

# %%
sp.expand(Acal_har_sub.subs(d11_M2_subs))
# Out:
#           2
# ⎛d       ⎞
# ⎜──(H(r))⎟
# ⎝dr      ⎠
# ───────────
#      3
#   3⋅H (r)

# %%
sp.expand(Bcal_har_sub.subs(d11_M2_subs))
# Out:
#            2
#  ⎛d       ⎞
# -⎜──(H(r))⎟
#  ⎝dr      ⎠
# ─────────────
#       2
#    6⋅H (r)

# %%
sp.expand(Ccal_har_sub.subs(d11_M2_subs))
# Out:
#           2
# ⎛d       ⎞
# ⎜──(H(r))⎟
# ⎝dr      ⎠
# ───────────
#      2
#   2⋅H (r)

# %% [markdown]
# ## Using kelly's formula for 11d M5

# %%
sp.expand(Acal_har_sub.subs(d11_M5_subs))
# Out:
#           2
# ⎛d       ⎞
# ⎜──(H(r))⎟
# ⎝dr      ⎠
# ───────────
#      3
#   6⋅H (r)

# %%
sp.expand(Bcal_har_sub.subs(d11_M5_subs))
# Out:
#            2
#  ⎛d       ⎞
# -⎜──(H(r))⎟
#  ⎝dr      ⎠
# ─────────────
#       2
#    3⋅H (r)

# %%
sp.expand(Ccal_har_sub.subs(d11_M5_subs))
# Out:
#           2
# ⎛d       ⎞
# ⎜──(H(r))⎟
# ⎝dr      ⎠
# ───────────
#      2
#   2⋅H (r)

# %% [markdown]
# ## Using Kelly's formula for 10d D3

# %%
sp.expand(Acal_har_sub.subs(d10_D3_subs))
# Out:
#           2
# ⎛d       ⎞
# ⎜──(H(r))⎟
# ⎝dr      ⎠
# ───────────
#      3
#   4⋅H (r)

# %%
sp.expand(Bcal_har_sub.subs(d10_D3_subs))
# Out:
#            2
#  ⎛d       ⎞
# -⎜──(H(r))⎟
#  ⎝dr      ⎠
# ─────────────
#       2
#    4⋅H (r)

# %%
sp.expand(Ccal_har_sub.subs(d10_D3_subs))
# Out:
#           2
# ⎛d       ⎞
# ⎜──(H(r))⎟
# ⎝dr      ⎠
# ───────────
#      2
#   2⋅H (r)

# %% [markdown]
# # Computing things using my code

# %%
import sympy as sp
from helpers.form_helpers import *
from helpers.einstein_helpers import *

# %% [markdown]
# ## checks for 10=4+6

# %%
# coordinates
x = sp.symbols('x0:4', real=True)
y = sp.symbols('y0:6', real=True)
coords = (*x,*y)
n = len(coords)

# Parameters and symbols
apar, bpar = sp.symbols('a b', real=True)
r_sym = sp.symbols('r', real=True, positive=True)

# expressions for radial coordinate r and r**2
r2 = sum(y_i**2 for y_i in y)
r = sp.sqrt(r2)

# harmonic function H, both as function of r, and as symbols
H = sp.Function('H')(r)
H_, H_p, H_pp = sp.symbols("H H' H''")
HARMONIC_DIMENSIONS = 6


print(f"We are in {n} dimensions, with coordinates {coords}")
print(f"Radial coordinate r = {r}, r^2 = {r2}")
print(f"Harmonic function H is harmonic in {HARMONIC_DIMENSIONS} dimensions.")
# Out:
# We are in 10 dimensions, with coordinates (x0, x1, x2, x3, y0, y1, y2, y3, y4, y5)
# Radial coordinate r = sqrt(y0**2 + y1**2 + y2**2 + y3**2 + y4**2 + y5**2), r^2 = y0**2 + y1**2 + y2**2 + y3**2 + y4**2 + y5**2
# Harmonic function H is harmonic in 6 dimensions.

# %%
# metric
g_MN = sp.zeros(n)
g_MN[0:4,0:4] = H**apar * sp.diag(-1, 1, 1, 1)
g_MN[4:n,4:n] = H**bpar * sp.eye(6)
g = sp.simplify(sp.sqrt(-(sp.det(g_MN))))
g_MN = sp.simplify(g_MN)

inv_g_MN = g_MN.inv()

# %%
# standard substitution procedure for later simplifications
def standard_subs(expr):
    """
    Substitutes sympy derivatives on function H(r) with symbols H, H', H''
    Then imposes the harmonic condition on H(r)

    Should be applied after derivatives have been computed
    """
    expr = sp.simplify(expr)
    expr = sp.simplify(expr.subs({H:H_,
                                  sp.sqrt(r2): r_sym,}))
    expr = sp.simplify(expr.subs({sp.Derivative(sp.Function('H')(r_sym), r_sym): H_p,
                                  sp.Derivative(sp.Function('H')(r_sym), (r_sym, 2)): H_pp}))
    expr = sp.simplify(impose_harmonic_condition_sym(expr, HARMONIC_DIMENSIONS, H_pp, H_p, r_sym))
    return expr

# %%
R_MN = ricci_tensor(g_MN, coords)
# Out:
# Computed Gamma^0_...,Computed Gamma^1_...,Computed Gamma^2_...,Computed Gamma^3_...,Computed Gamma^4_...,Computed Gamma^5_...,Computed Gamma^6_...,Computed Gamma^7_...,Computed Gamma^8_...,Computed Gamma^9_...,Computed R[0,...],Computed R[1,...],Computed R[2,...],Computed R[3,...],Computed R[4,...],Computed R[5,...],Computed R[6,...],Computed R[7,...],Computed R[8,...],Computed R[9,...],

# %%
sp.simplify(standard_subs(R_MN[0,0]))
# Out:
#  a - b - 2   2   ⎛      2         2         2         2         2         2    ↪
# H         ⋅H' ⋅a⋅⎝2⋅a⋅y₀  + 2⋅a⋅y₁  + 2⋅a⋅y₂  + 2⋅a⋅y₃  + 2⋅a⋅y₄  + 2⋅a⋅y₅  +  ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪       2         2         2         2         2         2     2     2     2  ↪
# ↪ 2⋅b⋅y₀  + 2⋅b⋅y₁  + 2⋅b⋅y₂  + 2⋅b⋅y₃  + 2⋅b⋅y₄  + 2⋅b⋅y₅  - y₀  - y₁  - y₂   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪          2                                                                   ↪
# ↪       2⋅r                                                                    ↪
#
# ↪     2     2     2⎞
# ↪ - y₃  - y₄  - y₅ ⎠
# ↪ ──────────────────
# ↪
# ↪

# %%
R_44 = R_MN[4,4]
R_44 = standard_subs(R_44)
R_44 = sp.simplify(R_44.subs({apar: -sp.Rational(1,2), bpar: sp.Rational(1,2)}))
R_44
# Out:
#    ⎛       2       ⎛  2     2     2     2     2     2⎞        ⎛    2     2     ↪
# H'⋅⎝- 6⋅H⋅r  + 6⋅H⋅⎝y₀  + y₁  + y₂  + y₃  + y₄  + y₅ ⎠ + H'⋅r⋅⎝- y₀  + y₁  + y ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                  2  3                          ↪
#                                               4⋅H ⋅r                           ↪
#
# ↪  2     2     2     2⎞⎞
# ↪ ₂  + y₃  + y₄  + y₅ ⎠⎠
# ↪ ──────────────────────
# ↪
# ↪

# %%
R_44 = sp.simplify(R_44.subs({r2: r_sym**2,
                              r2-y[0]**2: r_sym**2 - y[0]**2}))

# %%
R_44
# Out:
#   2 ⎛ 2       2⎞
# H' ⋅⎝r  - 2⋅y₀ ⎠
# ────────────────
#        2  2
#     4⋅H ⋅r

# %% [markdown]
# ## checks for 11=3+8

# %%
# coordinates
x = sp.symbols('x0:3', real=True)
y = sp.symbols('y0:8', real=True)
coords = (*x,*y)
n = len(coords)

# Parameters and symbols
apar, bpar = sp.symbols('a b', real=True)
r_sym = sp.symbols('r', real=True, positive=True)

# expressions for radial coordinate r and r**2
r2 = sum(y_i**2 for y_i in y)
r = sp.sqrt(r2)

# harmonic function H, both as function of r, and as symbols
H = sp.Function('H')(r)
H_, H_p, H_pp = sp.symbols("H H' H''")
HARMONIC_DIMENSIONS = 8


print(f"We are in {n} dimensions, with coordinates {coords}")
print(f"Radial coordinate r = {r}, r^2 = {r2}")
print(f"Harmonic function H is harmonic in {HARMONIC_DIMENSIONS} dimensions.")
# Out:
# We are in 11 dimensions, with coordinates (x0, x1, x2, y0, y1, y2, y3, y4, y5, y6, y7)
# Radial coordinate r = sqrt(y0**2 + y1**2 + y2**2 + y3**2 + y4**2 + y5**2 + y6**2 + y7**2), r^2 = y0**2 + y1**2 + y2**2 + y3**2 + y4**2 + y5**2 + y6**2 + y7**2
# Harmonic function H is harmonic in 8 dimensions.

# %%
# metric
g_MN = sp.zeros(n)
g_MN[0:3,0:3] = H**apar * sp.diag(-1, 1, 1)
g_MN[3:n,3:n] = H**bpar * sp.eye(8)
g = sp.simplify(sp.sqrt(-(sp.det(g_MN))))
g_MN = sp.simplify(g_MN)

inv_g_MN = g_MN.inv()

# %%
# standard substitution procedure for later simplifications
def standard_subs(expr):
    """
    Substitutes sympy derivatives on function H(r) with symbols H, H', H''
    Then imposes the harmonic condition on H(r)

    Should be applied after derivatives have been computed
    """
    expr = sp.simplify(expr)
    expr = sp.simplify(expr.subs({H:H_,
                                  sp.sqrt(r2): r_sym,}))
    expr = sp.simplify(expr.subs({sp.Derivative(sp.Function('H')(r_sym), r_sym): H_p,
                                  sp.Derivative(sp.Function('H')(r_sym), (r_sym, 2)): H_pp}))
    expr = sp.simplify(impose_harmonic_condition_sym(expr, HARMONIC_DIMENSIONS, H_pp, H_p, r_sym))
    return expr

# %%
R_MN = ricci_tensor(g_MN, coords)
# Out:
# Computed Gamma^0_...,Computed Gamma^1_...,Computed Gamma^2_...,Computed Gamma^3_...,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 R_MN = ricci_tensor(g_MN, coords)
#
# File c:\Users\dc1624\Documents\brane_solns\helpers\einstein_helpers.py:33, in ricci_tensor(metric, coordinates)
#      31     d_gNQ_dXP = sp.diff(metric[N,Q], coordinates[P])
#      32     d_gPQ_dXN = sp.diff(metric[P,Q], coordinates[N])
# ---> 33     d_gNP_dXQ = sp.diff(metric[N,P], coordinates[Q])
#      34     sum_term += inv_metric[M,Q] * (d_gNQ_dXP + d_gPQ_dXN - d_gNP_dXQ)
#      35 Gamma[M][N][P] = sp.simplify(sp.Rational(1,2) * sum_term)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:2511, in diff(f, *symbols, **kwargs)
#    2447 """
#    2448 Differentiate f with respect to symbols.
#    2449
#    (...)   2508
#    2509 """
#    2510 if hasattr(f, 'diff'):
# -> 2511     return f.diff(*symbols, **kwargs)
#    2512 kwargs.setdefault('evaluate', True)
#    2513 return _derivative_dispatch(f, *symbols, **kwargs)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:1466, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     if not old_v.is_scalar and not hasattr(
#    1460             old_v, '_eval_derivative'):
#    1461         # special hack providing evaluation for classes
#    1462         # that have defined is_scalar=True but have no
#    1463         # _eval_derivative defined
#    1464         expr *= old_v.diff(old_v)
# -> 1466 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1467 if obj is not None and obj.is_zero:
#    1468     return obj
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:1927, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1921 @classmethod
#    1922 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1923     # Evaluate the derivative `n` times.  If
#    1924     # `_eval_derivative_n_times` is not overridden by the current
#    1925     # object, the default in `Basic` will call a loop over
#    1926     # `_eval_derivative`:
# -> 1927     return expr._eval_derivative_n_times(v, count)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\basic.py:1975, in Basic._eval_derivative_n_times(self, s, n)
#    1973 for i in range(n):
#    1974     prev = obj
# -> 1975     obj = obj._eval_derivative(s)
#    1976     if obj is None:
#    1977         return None
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\power.py:1221, in Pow._eval_derivative(self, s)
#    1219 def _eval_derivative(self, s):
#    1220     from sympy.functions.elementary.exponential import log
# -> 1221     dbase = self.base.diff(s)
#    1222     dexp = self.exp.diff(s)
#    1223     return self * (dexp * log(self.base) + dbase * self.exp/self.base)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:1466, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1459     if not old_v.is_scalar and not hasattr(
#    1460             old_v, '_eval_derivative'):
#    1461         # special hack providing evaluation for classes
#    1462         # that have defined is_scalar=True but have no
#    1463         # _eval_derivative defined
#    1464         expr *= old_v.diff(old_v)
# -> 1466 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1467 if obj is not None and obj.is_zero:
#    1468     return obj
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\function.py:1927, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1921 @classmethod
#    1922 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1923     # Evaluate the derivative `n` times.  If
#    1924     # `_eval_derivative_n_times` is not overridden by the current
#    1925     # object, the default in `Basic` will call a loop over
#    1926     # `_eval_derivative`:
# -> 1927     return expr._eval_derivative_n_times(v, count)
#
# File c:\Users\dc1624\AppData\Local\miniconda3\envs\branes\Lib\site-packages\sympy\core\basic.py:1963, in Basic._eval_derivative_n_times(self, s, n)
#    1960     from sympy.assumptions.refine import refine
#    1961     return refine(self, assumption)
# -> 1963 def _eval_derivative_n_times(self, s, n):
#    1964     # This is the default evaluator for derivatives (as called by `diff`
#    1965     # and `Derivative`), it will attempt a loop to derive the expression
#    1966     # `n` times by calling the corresponding `_eval_derivative` method,
#    1967     # while leaving the derivative unevaluated if `n` is symbolic.  This
#    1968     # method should be overridden if the object has a closed form for its
#    1969     # symbolic n-th derivative.
#    1970     from .numbers import Integer
#    1971     if isinstance(n, (int, Integer)):
#
# KeyboardInterrupt:

# %%
sp.simplify(standard_subs(R_MN[0,0]))
# Out:
#  a - b - 2   2   ⎛      2         2         2         2         2         2    ↪
# H         ⋅H' ⋅a⋅⎝3⋅a⋅y₀  + 3⋅a⋅y₁  + 3⋅a⋅y₂  + 3⋅a⋅y₃  + 3⋅a⋅y₄  + 3⋅a⋅y₅  +  ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪       2         2         2         2         2         2         2          ↪
# ↪ 3⋅a⋅y₆  + 3⋅a⋅y₇  + 6⋅b⋅y₀  + 6⋅b⋅y₁  + 6⋅b⋅y₂  + 6⋅b⋅y₃  + 6⋅b⋅y₄  + 6⋅b⋅y₅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                            2                                 ↪
# ↪                                         4⋅r                                  ↪
#
# ↪ 2         2         2       2       2       2       2       2       2        ↪
# ↪   + 6⋅b⋅y₆  + 6⋅b⋅y₇  - 2⋅y₀  - 2⋅y₁  - 2⋅y₂  - 2⋅y₃  - 2⋅y₄  - 2⋅y₅  - 2⋅y₆ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ 2       2⎞
# ↪   - 2⋅y₇ ⎠
# ↪ ──────────
# ↪
# ↪

# %%
R_33 = R_MN[3,3]
R_33 = standard_subs(R_33)
R_33 = sp.simplify(R_33.subs({apar: -sp.Rational(2,3), bpar: sp.Rational(1,3)}))
R_33
# Out:
#    ⎛       2       ⎛  2     2     2     2     2     2     2     2⎞        ⎛    ↪
# H'⋅⎝- 8⋅H⋅r  + 8⋅H⋅⎝y₀  + y₁  + y₂  + y₃  + y₄  + y₅  + y₆  + y₇ ⎠ + H'⋅r⋅⎝- 2 ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                               2  3             ↪
#                                                            6⋅H ⋅r              ↪
#
# ↪    2     2     2     2     2     2     2     2⎞⎞
# ↪ ⋅y₀  + y₁  + y₂  + y₃  + y₄  + y₅  + y₆  + y₇ ⎠⎠
# ↪ ────────────────────────────────────────────────
# ↪
# ↪

# %%
R_33 = sp.simplify(R_33.subs({r2: r_sym**2,
                              r2-y[0]**2: r_sym**2 - y[0]**2}))
R_33
# Out:
#   2 ⎛ 2       2⎞
# H' ⋅⎝r  - 3⋅y₀ ⎠
# ────────────────
#        2  2
#     6⋅H ⋅r

# %% [markdown]
# ## checks for 11 = 6 + 5

# %%
# coordinates
x = sp.symbols('x0:6', real=True)
y = sp.symbols('y0:5', real=True)
coords = (*x,*y)
n = len(coords)

# Parameters and symbols
apar, bpar = sp.symbols('a b', real=True)
r_sym = sp.symbols('r', real=True, positive=True)

# expressions for radial coordinate r and r**2
r2 = sum(y_i**2 for y_i in y)
r = sp.sqrt(r2)

# harmonic function H, both as function of r, and as symbols
H = sp.Function('H')(r)
H_, H_p, H_pp = sp.symbols("H H' H''")
HARMONIC_DIMENSIONS = 5


print(f"We are in {n} dimensions, with coordinates {coords}")
print(f"Radial coordinate r = {r}, r^2 = {r2}")
print(f"Harmonic function H is harmonic in {HARMONIC_DIMENSIONS} dimensions.")
# Out:
# We are in 11 dimensions, with coordinates (x0, x1, x2, x3, x4, x5, y0, y1, y2, y3, y4)
# Radial coordinate r = sqrt(y0**2 + y1**2 + y2**2 + y3**2 + y4**2), r^2 = y0**2 + y1**2 + y2**2 + y3**2 + y4**2
# Harmonic function H is harmonic in 5 dimensions.

# %%
# metric
g_MN = sp.zeros(n)
g_MN[0:6,0:6] = H**apar * sp.diag(-1, 1, 1, 1, 1, 1)
g_MN[6:n,6:n] = H**bpar * sp.eye(5)
g = sp.simplify(sp.sqrt(-(sp.det(g_MN))))
g_MN = sp.simplify(g_MN)

inv_g_MN = g_MN.inv()

# %%
# standard substitution procedure for later simplifications
def standard_subs(expr):
    """
    Substitutes sympy derivatives on function H(r) with symbols H, H', H''
    Then imposes the harmonic condition on H(r)

    Should be applied after derivatives have been computed
    """
    expr = sp.simplify(expr)
    expr = sp.simplify(expr.subs({H:H_,
                                  sp.sqrt(r2): r_sym,}))
    expr = sp.simplify(expr.subs({sp.Derivative(sp.Function('H')(r_sym), r_sym): H_p,
                                  sp.Derivative(sp.Function('H')(r_sym), (r_sym, 2)): H_pp}))
    expr = sp.simplify(impose_harmonic_condition_sym(expr, HARMONIC_DIMENSIONS, H_pp, H_p, r_sym))
    return expr

# %%
R_MN = ricci_tensor(g_MN, coords)
# Out:
# Computed Gamma^0_...
# Computed Gamma^1_...
# Computed Gamma^2_...
# Computed Gamma^3_...
# Computed Gamma^4_...
# Computed Gamma^5_...
# Computed Gamma^6_...
# Computed Gamma^7_...
# Computed Gamma^8_...
# Computed Gamma^9_...
# Computed Gamma^10_...
# Computed R[0,...]
# Computed R[1,...]
# Computed R[2,...]
# Computed R[3,...]
# Computed R[4,...]
# Computed R[5,...]
# Computed R[6,...]
# Computed R[7,...]
# Computed R[8,...]
# Computed R[9,...]
# Computed R[10,...]

# %%
sp.simplify(standard_subs(R_MN[0,0]))
# Out:
#  a - b - 2   2   ⎛      2         2         2         2         2         2    ↪
# H         ⋅H' ⋅a⋅⎝6⋅a⋅y₀  + 6⋅a⋅y₁  + 6⋅a⋅y₂  + 6⋅a⋅y₃  + 6⋅a⋅y₄  + 3⋅b⋅y₀  +  ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                             4⋅ ↪
#
# ↪       2         2         2         2       2       2       2       2        ↪
# ↪ 3⋅b⋅y₁  + 3⋅b⋅y₂  + 3⋅b⋅y₃  + 3⋅b⋅y₄  - 2⋅y₀  - 2⋅y₁  - 2⋅y₂  - 2⋅y₃  - 2⋅y₄ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪  2                                                                           ↪
# ↪ r                                                                            ↪
#
# ↪ 2⎞
# ↪  ⎠
# ↪ ──
# ↪
# ↪

# %%
R_66 = R_MN[6,6]
R_66 = standard_subs(R_66)
R_66 = sp.simplify(R_66.subs({apar: -sp.Rational(1,3), bpar: sp.Rational(2,3)}))
R_66
# Out:
#    ⎛        2        ⎛  2     2     2     2     2⎞        ⎛    2       2       ↪
# H'⋅⎝- 10⋅H⋅r  + 10⋅H⋅⎝y₀  + y₁  + y₂  + y₃  + y₄ ⎠ + H'⋅r⋅⎝- y₀  + 2⋅y₁  + 2⋅y ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                 2  3                           ↪
#                                              6⋅H ⋅r                            ↪
#
# ↪  2       2       2⎞⎞
# ↪ ₂  + 2⋅y₃  + 2⋅y₄ ⎠⎠
# ↪ ────────────────────
# ↪
# ↪

# %%
R_66 = sp.simplify(R_66.subs({r2: r_sym**2,
                              r2-y[0]**2: r_sym**2 - y[0]**2,
                              2*(r2-y[0]**2): 2*(r_sym**2 - y[0]**2)}))
R_66
# Out:
#     ⎛ 2     2⎞
#   2 ⎜r    y₀ ⎟
# H' ⋅⎜── - ───⎟
#     ⎝3     2 ⎠
# ──────────────
#      2  2
#     H ⋅r
