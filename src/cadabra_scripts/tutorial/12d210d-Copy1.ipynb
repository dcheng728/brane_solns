# %%
# ============================================================
#  12D -> 10D block-diagonal reduction
#  G_{\mu\nu} = g_{mn} \oplus H_{ab},   \partial_a = 0
# ============================================================

{\mu,\nu,\rho,\sigma,\kappa,\lambda,\eta,\chi#}::Indices(full, position=independent);
{m,n,p,q,r,s,t,u,v,w,x,y,z,m#}::Indices(spacetime, position=independent, parent=full);
{a,b,c,d,e,f,a#}::Indices(internal, position=independent, parent=full);

\partial{#}::PartialDerivative.
G_{\mu\nu}::Metric.
G^{\mu\nu}::InverseMetric.
G_{\mu? \nu?}::Symmetric.
G^{\mu? \nu?}::Symmetric.
g_{m n}::Metric.
g^{m n}::InverseMetric.
g_{m? n?}::Symmetric.
g^{m? n?}::Symmetric.
H_{a b}::Symmetric.
H^{a b}::Symmetric.
\delta^{\mu?}_{\nu?}::KroneckerDelta.
\delta_{\mu?}^{\nu?}::KroneckerDelta.

RtoG:= R^{\lambda?}_{\mu?\nu?\kappa?} -> 
 - \partial_{\kappa?}{ \Gamma^{\lambda?}_{\mu?\nu?} }
 + \partial_{\nu?}{ \Gamma^{\lambda?}_{\mu?\kappa?} }
 - \Gamma^{\eta}_{\mu?\nu?} \Gamma^{\lambda?}_{\kappa?\eta}
 + \Gamma^{\eta}_{\mu?\kappa?} \Gamma^{\lambda?}_{\nu?\eta};

GtoG:= \Gamma^{\lambda?}_{\mu?\nu?} ->
  (1/2) * G^{\lambda?\kappa?} ( 
        \partial_{\nu?}{ G_{\kappa?\mu?} } + \partial_{\mu?}{ G_{\kappa?\nu?} } - \partial_{\kappa?}{ G_{\mu?\nu?} } );
# Out:
# ${}\text{Property Indices(position=independent) attached to}\left[\mu, \nu, \rho, \sigma, \kappa, \lambda, \eta, \chi\#\right].$
# ${}\text{Property Indices(position=independent) attached to}\left[m, n, p, q, r, s, t, u, v, w, x, y, z, m\#\right].$
# ${}\text{Property Indices(position=independent) attached to}\left[a, b, c, d, e, f, a\#\right].$
# ${}R^{\lambda?}\,_{\mu? \nu? \kappa?} \rightarrow -\,\partial_{\kappa?}{\Gamma^{\lambda?}\,_{\mu? \nu?}}+\partial_{\nu?}{\Gamma^{\lambda?}\,_{\mu? \kappa?}}-\,\Gamma^{\eta}\,_{\mu? \nu?} \Gamma^{\lambda?}\,_{\kappa? \eta}+\Gamma^{\eta}\,_{\mu? \kappa?} \Gamma^{\lambda?}\,_{\nu? \eta}$
# ${}\Gamma^{\lambda?}\,_{\mu? \nu?} \rightarrow \frac{1}{2}\,G^{\lambda? \kappa?} \left(\partial_{\nu?}{G_{\kappa? \mu?}}+\partial_{\mu?}{G_{\kappa? \nu?}}-\,\partial_{\kappa?}{G_{\mu? \nu?}}\right)$

# %%
def KK_index_split(ex):
    split_index(ex, $\mu, m, a$, repeat=True)
    split_index(ex, $\mu, m, a$, repeat=True)
    return ex

def KK_ansatze(ex):
    KK_index_split(ex)
    substitute(ex, $G_{m a} -> 0$, repeat = True)
    substitute(ex, $G_{a m} -> 0$, repeat = True)
    substitute(ex, $G^{m a} -> 0$, repeat = True)
    substitute(ex, $G^{a m} -> 0$, repeat = True)
    substitute(ex, $\partial_{a}{A??} -> 0$, repeat = True)
    substitute(ex, $\partial_{a b}{A??} -> 0$, repeat = True)
    substitute(ex, $\partial_{a m}{A??} -> 0$, repeat = True)
    substitute(ex, $\partial_{m a}{A??} -> 0$, repeat = True)
    return ex

# %%
_;
# Out:
# ${}\Gamma^{\lambda?}\,_{\mu? \nu?} \rightarrow \frac{1}{2}\,G^{\lambda? \kappa?} \left(\partial_{\nu?}{G_{\kappa? \mu?}}+\partial_{\mu?}{G_{\kappa? \nu?}}-\,\partial_{\kappa?}{G_{\mu? \nu?}}\right)$

# %%
# ============================================================
#  Full R_{\mu\rho\nu\sigma} in terms of metric
# ============================================================
Rfull:= G_{A? B?} R^{B?}_{C? B? D?};

substitute(_, RtoG)
substitute(_, GtoG)
distribute(_)
product_rule(_)
distribute(_)
sort_product(_);
# Out:
# ${}G_{A? B?} R^{B?}\,_{C? B? D?}$
# ${} - \frac{1}{2}\,G_{A? B?} \partial_{B?}{G_{\kappa? C?}} \partial_{D?}{G^{B? \kappa?}} - \frac{1}{2}\,G_{A? B?} G^{B? \kappa?} \partial_{D? B?}{G_{\kappa? C?}} - \frac{1}{2}\,G_{A? B?} \partial_{C?}{G_{\kappa? B?}} \partial_{D?}{G^{B? \kappa?}} - \frac{1}{2}\,G_{A? B?} G^{B? \kappa?} \partial_{D? C?}{G_{\kappa? B?}}+\frac{1}{2}\,G_{A? B?} \partial_{\kappa?}{G_{C? B?}} \partial_{D?}{G^{B? \kappa?}}+\frac{1}{2}\,G_{A? B?} G^{B? \kappa?} \partial_{D? \kappa?}{G_{C? B?}}+\frac{1}{2}\,G_{A? B?} \partial_{D?}{G_{\kappa? C?}} \partial_{B?}{G^{B? \kappa?}}+\frac{1}{2}\,G_{A? B?} G^{B? \kappa?} \partial_{B? D?}{G_{\kappa? C?}}+\frac{1}{2}\,G_{A? B?} \partial_{C?}{G_{\kappa? D?}} \partial_{B?}{G^{B? \kappa?}}+\frac{1}{2}\,G_{A? B?} G^{B? \kappa?} \partial_{B? C?}{G_{\kappa? D?}} - \frac{1}{2}\,G_{A? B?} \partial_{\kappa?}{G_{C? D?}} \partial_{B?}{G^{B? \kappa?}} - \frac{1}{2}\,G_{A? B?} G^{B? \kappa?} \partial_{B? \kappa?}{G_{C? D?}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{B?}{G_{\kappa? C?}} \partial_{\eta}{G_{\kappa? D?}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{B?}{G_{\kappa? C?}} \partial_{D?}{G_{\kappa? \eta}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{B?}{G_{\kappa? C?}} \partial_{\kappa?}{G_{D? \eta}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{C?}{G_{\kappa? B?}} \partial_{\eta}{G_{\kappa? D?}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{C?}{G_{\kappa? B?}} \partial_{D?}{G_{\kappa? \eta}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{C?}{G_{\kappa? B?}} \partial_{\kappa?}{G_{D? \eta}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{\kappa?}{G_{C? B?}} \partial_{\eta}{G_{\kappa? D?}}%
# +\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{\kappa?}{G_{C? B?}} \partial_{D?}{G_{\kappa? \eta}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{\kappa?}{G_{C? B?}} \partial_{\kappa?}{G_{D? \eta}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{D?}{G_{\kappa? C?}} \partial_{\eta}{G_{\kappa? B?}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{D?}{G_{\kappa? C?}} \partial_{B?}{G_{\kappa? \eta}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{D?}{G_{\kappa? C?}} \partial_{\kappa?}{G_{B? \eta}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{C?}{G_{\kappa? D?}} \partial_{\eta}{G_{\kappa? B?}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{C?}{G_{\kappa? D?}} \partial_{B?}{G_{\kappa? \eta}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{C?}{G_{\kappa? D?}} \partial_{\kappa?}{G_{B? \eta}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{\kappa?}{G_{C? D?}} \partial_{\eta}{G_{\kappa? B?}} - \frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{\kappa?}{G_{C? D?}} \partial_{B?}{G_{\kappa? \eta}}+\frac{1}{4}\,G_{A? B?} G^{B? \kappa?} G^{\eta \kappa?} \partial_{\kappa?}{G_{C? D?}} \partial_{\kappa?}{G_{B? \eta}}$

# %%
X:= _ -> R_{A?C?B?D?}

# %%
X;
# Out:
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.14/site-packages/cadabra2_jupyter/kernel.py", line 57, in do_execute
#     self._execute_python(pycode)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/opt/homebrew/lib/python3.14/site-packages/cadabra2_jupyter/kernel.py", line 111, in _execute_python
#     self._sandbox_context(pycode)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/opt/homebrew/lib/python3.14/site-packages/cadabra2_jupyter/context.py", line 52, in __call__
#     exec(code, self._sandbox)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'X' is not defined

# %%
# ============================================================
#  R_{mpnq}
# ============================================================
Rmpnq:= G_{\mu m} R^{\mu}_{p n q};
# Out:
# ${}G_{\mu m} R^{\mu}\,_{p n q}$

# %%
# ============================================================
#  Split all indices, impose block-diagonal + \partial_a = 0
# ============================================================
substitute(_, RtoG)
substitute(_, GtoG)
distribute(_)
product_rule(_)
distribute(_)
sort_product(_);
# Out:
# ${} - \frac{1}{2}\,G_{\mu m} \partial_{n}{G_{\kappa? p}} \partial_{q}{G^{\mu \kappa?}} - \frac{1}{2}\,G_{\mu m} G^{\mu \kappa?} \partial_{q n}{G_{\kappa? p}} - \frac{1}{2}\,G_{\mu m} \partial_{p}{G_{\kappa? n}} \partial_{q}{G^{\mu \kappa?}} - \frac{1}{2}\,G_{\mu m} G^{\mu \kappa?} \partial_{q p}{G_{\kappa? n}}+\frac{1}{2}\,G_{\mu m} \partial_{\kappa?}{G_{p n}} \partial_{q}{G^{\mu \kappa?}}+\frac{1}{2}\,G_{\mu m} G^{\mu \kappa?} \partial_{q \kappa?}{G_{p n}}+\frac{1}{2}\,G_{\mu m} \partial_{q}{G_{\kappa? p}} \partial_{n}{G^{\mu \kappa?}}+\frac{1}{2}\,G_{\mu m} G^{\mu \kappa?} \partial_{n q}{G_{\kappa? p}}+\frac{1}{2}\,G_{\mu m} \partial_{p}{G_{\kappa? q}} \partial_{n}{G^{\mu \kappa?}}+\frac{1}{2}\,G_{\mu m} G^{\mu \kappa?} \partial_{n p}{G_{\kappa? q}} - \frac{1}{2}\,G_{\mu m} \partial_{\kappa?}{G_{p q}} \partial_{n}{G^{\mu \kappa?}} - \frac{1}{2}\,G_{\mu m} G^{\mu \kappa?} \partial_{n \kappa?}{G_{p q}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\eta}{G_{\kappa? q}} \partial_{n}{G_{\kappa? p}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{q}{G_{\kappa? \eta}} \partial_{n}{G_{\kappa? p}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{n}{G_{\kappa? p}} \partial_{\kappa?}{G_{q \eta}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\eta}{G_{\kappa? q}} \partial_{p}{G_{\kappa? n}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{q}{G_{\kappa? \eta}} \partial_{p}{G_{\kappa? n}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{p}{G_{\kappa? n}} \partial_{\kappa?}{G_{q \eta}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\kappa?}{G_{p n}} \partial_{\eta}{G_{\kappa? q}}%
# +\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\kappa?}{G_{p n}} \partial_{q}{G_{\kappa? \eta}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\kappa?}{G_{q \eta}} \partial_{\kappa?}{G_{p n}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\eta}{G_{\kappa? n}} \partial_{q}{G_{\kappa? p}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{n}{G_{\kappa? \eta}} \partial_{q}{G_{\kappa? p}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{q}{G_{\kappa? p}} \partial_{\kappa?}{G_{n \eta}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\eta}{G_{\kappa? n}} \partial_{p}{G_{\kappa? q}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{n}{G_{\kappa? \eta}} \partial_{p}{G_{\kappa? q}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{p}{G_{\kappa? q}} \partial_{\kappa?}{G_{n \eta}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\eta}{G_{\kappa? n}} \partial_{\kappa?}{G_{p q}} - \frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\kappa?}{G_{p q}} \partial_{n}{G_{\kappa? \eta}}+\frac{1}{4}\,G_{\mu m} G^{\eta \kappa?} G^{\mu \kappa?} \partial_{\kappa?}{G_{n \eta}} \partial_{\kappa?}{G_{p q}}$

# %%
# KK_index_split(_);

# %%
KK_ansatze(_);
# Out:
# ${} - \frac{1}{2}\,G_{r m} \partial_{n}{G_{\kappa? p}} \partial_{q}{G^{r \kappa?}} - \frac{1}{2}\,G_{r m} G^{r \kappa?} \partial_{q n}{G_{\kappa? p}} - \frac{1}{2}\,G_{r m} \partial_{p}{G_{\kappa? n}} \partial_{q}{G^{r \kappa?}} - \frac{1}{2}\,G_{r m} G^{r \kappa?} \partial_{q p}{G_{\kappa? n}}+\frac{1}{2}\,G_{r m} \partial_{\kappa?}{G_{p n}} \partial_{q}{G^{r \kappa?}}+\frac{1}{2}\,G_{r m} G^{r \kappa?} \partial_{q \kappa?}{G_{p n}}+\frac{1}{2}\,G_{r m} \partial_{q}{G_{\kappa? p}} \partial_{n}{G^{r \kappa?}}+\frac{1}{2}\,G_{r m} G^{r \kappa?} \partial_{n q}{G_{\kappa? p}}+\frac{1}{2}\,G_{r m} \partial_{p}{G_{\kappa? q}} \partial_{n}{G^{r \kappa?}}+\frac{1}{2}\,G_{r m} G^{r \kappa?} \partial_{n p}{G_{\kappa? q}} - \frac{1}{2}\,G_{r m} \partial_{\kappa?}{G_{p q}} \partial_{n}{G^{r \kappa?}} - \frac{1}{2}\,G_{r m} G^{r \kappa?} \partial_{n \kappa?}{G_{p q}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{r}{G_{\kappa? q}} \partial_{n}{G_{\kappa? p}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{q}{G_{\kappa? r}} \partial_{n}{G_{\kappa? p}} - \frac{1}{4}\,G_{r m} G^{a \kappa?} G^{r \kappa?} \partial_{q}{G_{\kappa? a}} \partial_{n}{G_{\kappa? p}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{n}{G_{\kappa? p}} \partial_{\kappa?}{G_{q r}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{r}{G_{\kappa? q}} \partial_{p}{G_{\kappa? n}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{q}{G_{\kappa? r}} \partial_{p}{G_{\kappa? n}} - \frac{1}{4}\,G_{r m} G^{a \kappa?} G^{r \kappa?} \partial_{q}{G_{\kappa? a}} \partial_{p}{G_{\kappa? n}}%
# +\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{p}{G_{\kappa? n}} \partial_{\kappa?}{G_{q r}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{\kappa?}{G_{p n}} \partial_{r}{G_{\kappa? q}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{\kappa?}{G_{p n}} \partial_{q}{G_{\kappa? r}}+\frac{1}{4}\,G_{r m} G^{a \kappa?} G^{r \kappa?} \partial_{\kappa?}{G_{p n}} \partial_{q}{G_{\kappa? a}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{\kappa?}{G_{q r}} \partial_{\kappa?}{G_{p n}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{r}{G_{\kappa? n}} \partial_{q}{G_{\kappa? p}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{n}{G_{\kappa? r}} \partial_{q}{G_{\kappa? p}}+\frac{1}{4}\,G_{r m} G^{a \kappa?} G^{r \kappa?} \partial_{n}{G_{\kappa? a}} \partial_{q}{G_{\kappa? p}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{q}{G_{\kappa? p}} \partial_{\kappa?}{G_{n r}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{r}{G_{\kappa? n}} \partial_{p}{G_{\kappa? q}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{n}{G_{\kappa? r}} \partial_{p}{G_{\kappa? q}}+\frac{1}{4}\,G_{r m} G^{a \kappa?} G^{r \kappa?} \partial_{n}{G_{\kappa? a}} \partial_{p}{G_{\kappa? q}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{p}{G_{\kappa? q}} \partial_{\kappa?}{G_{n r}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{r}{G_{\kappa? n}} \partial_{\kappa?}{G_{p q}} - \frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{\kappa?}{G_{p q}} \partial_{n}{G_{\kappa? r}} - \frac{1}{4}\,G_{r m} G^{a \kappa?} G^{r \kappa?} \partial_{\kappa?}{G_{p q}} \partial_{n}{G_{\kappa? a}}+\frac{1}{4}\,G_{s m} G^{r \kappa?} G^{s \kappa?} \partial_{\kappa?}{G_{n r}} \partial_{\kappa?}{G_{p q}}$
