# %%
{i,j,m,n,k,p,q,l,r,r#}::Indices(vector).
C_{m n p q}::WeylTensor.
\nabla{#}::Derivative.
\nabla_{r}{ C_{m n p q} }::SatisfiesBianchi.
\delta_{i j}::KroneckerDelta.

Eij:=- C_{i m k l} C_{j p k q} C_{l p m q} + 1/4 C_{i m k l} C_{j m p q} C_{k l p q}
     - 1/2 C_{i k j l} C_{k m p q} C_{l m p q}:

E:=  C_{j m n k} C_{m p q n} C_{p j k q} + 1/2 C_{j k m n} C_{p q m n} C_{j k p q}:

exp:= \nabla_{i}{\nabla_{j}{ @(Eij) }} - 1/6 \nabla_{i}{\nabla_{i}{ @(E) }};
# Out:
# ${}-\,C_{i m k l} C_{j p k q} C_{l p m q}+\frac{1}{4}\,C_{i m k l} C_{j m p q} C_{k l p q} - \frac{1}{2}\,C_{i k j l} C_{k m p q} C_{l m p q}$
# ${}\nabla_{i}\left(\nabla_{j}\left(-\,C_{i m k l} C_{j p k q} C_{l p m q}+\frac{1}{4}\,C_{i m k l} C_{j m p q} C_{k l p q} - \frac{1}{2}\,C_{i k j l} C_{k m p q} C_{l m p q}\right)\right) - \frac{1}{6}\,\nabla_{i}\left(\nabla_{i}\left(C_{j m n k} C_{m p q n} C_{p j k q}+\frac{1}{2}\,C_{j k m n} C_{p q m n} C_{j k p q}\right)\right)$

# %%
distribute(_); product_rule(_); distribute(_); product_rule(_)
sort_product(_); canonicalise(_)
rename_dummies(_);
# Out:
# ${}C_{i j m n} C_{i k m p} \nabla_{q}\left(\nabla_{j}{C_{n k p q}}\right)-\,C_{i j m n} \nabla_{q}{C_{i k m p}} \nabla_{k}{C_{j p n q}}-2\,C_{i j m n} \nabla_{i}{C_{m k p q}} \nabla_{p}{C_{j k n q}}-\,C_{i j m n} \nabla_{k}{C_{i k m p}} \nabla_{q}{C_{j p n q}}+C_{i j m n} C_{i k m p} \nabla_{j}\left(\nabla_{q}{C_{n k p q}}\right)-2\,C_{i j m n} \nabla_{p}{C_{i k p q}} \nabla_{m}{C_{j q n k}}-\,C_{i j m n} C_{i k p q} \nabla_{m}\left(\nabla_{p}{C_{j q n k}}\right) - \frac{1}{4}\,C_{i j m n} C_{i j k p} \nabla_{q}\left(\nabla_{m}{C_{n q k p}}\right)+\frac{1}{4}\,C_{i j m n} \nabla_{q}{C_{i j k p}} \nabla_{k}{C_{m n q p}} - \frac{1}{2}\,C_{i j m n} \nabla_{i}{C_{j k p q}} \nabla_{k}{C_{m n p q}} - \frac{1}{4}\,C_{i j m n} \nabla_{k}{C_{i j k p}} \nabla_{q}{C_{m n p q}} - \frac{1}{4}\,C_{i j m n} C_{i j k p} \nabla_{m}\left(\nabla_{q}{C_{n q k p}}\right)+\frac{1}{2}\,C_{i j m n} \nabla_{k}{C_{i k p q}} \nabla_{j}{C_{m n p q}}+\frac{1}{4}\,C_{i j m n} C_{i k p q} \nabla_{j}\left(\nabla_{k}{C_{m n p q}}\right) - \frac{1}{2}\,C_{i j m n} C_{i j m k} \nabla_{p}\left(\nabla_{q}{C_{n p k q}}\right)-\,C_{i j m n} \nabla_{k}{C_{i k p q}} \nabla_{p}{C_{j q m n}}-\,C_{i j m n} \nabla_{p}{C_{i k p q}} \nabla_{k}{C_{j q m n}}+\frac{1}{2}\,C_{i j m n} C_{i k p q} \nabla_{m}\left(\nabla_{j}{C_{n k p q}}\right)+\frac{1}{2}\,C_{i j m n} \nabla_{i}{C_{m k p q}} \nabla_{n}{C_{j k p q}}%
#  - \frac{1}{2}\,C_{i j m n} \nabla_{i}{C_{j k p q}} \nabla_{m}{C_{n k p q}}+\frac{1}{2}\,C_{i j m n} C_{i k p q} \nabla_{j}\left(\nabla_{m}{C_{n k p q}}\right)+\frac{1}{2}\,C_{i j m n} C_{i k m p} \nabla_{q}\left(\nabla_{q}{C_{j k n p}}\right)+C_{i j m n} \nabla_{q}{C_{i k m p}} \nabla_{q}{C_{j k n p}} - \frac{1}{4}\,C_{i j m n} C_{i j k p} \nabla_{q}\left(\nabla_{q}{C_{m n k p}}\right) - \frac{1}{2}\,C_{i j m n} \nabla_{q}{C_{i j k p}} \nabla_{q}{C_{m n k p}}$

# %%
substitute(_, $\nabla_{i}{ C_{k i l m} } -> 0, \nabla_{i}{ C_{k m l i} } -> 0$);
# Out:
# ${}C_{i j m n} C_{i k m p} \nabla_{q}\left(\nabla_{j}{C_{n k p q}}\right)-\,C_{i j m n} \nabla_{q}{C_{i k m p}} \nabla_{k}{C_{j p n q}}-2\,C_{i j m n} \nabla_{i}{C_{m k p q}} \nabla_{p}{C_{j k n q}}-2\,C_{i j m n} \nabla_{p}{C_{i k p q}} \nabla_{m}{C_{j q n k}}-\,C_{i j m n} C_{i k p q} \nabla_{m}\left(\nabla_{p}{C_{j q n k}}\right) - \frac{1}{4}\,C_{i j m n} C_{i j k p} \nabla_{q}\left(\nabla_{m}{C_{n q k p}}\right)+\frac{1}{4}\,C_{i j m n} \nabla_{q}{C_{i j k p}} \nabla_{k}{C_{m n q p}} - \frac{1}{2}\,C_{i j m n} \nabla_{i}{C_{j k p q}} \nabla_{k}{C_{m n p q}}+\frac{1}{4}\,C_{i j m n} C_{i k p q} \nabla_{j}\left(\nabla_{k}{C_{m n p q}}\right)-\,C_{i j m n} \nabla_{p}{C_{i k p q}} \nabla_{k}{C_{j q m n}}+\frac{1}{2}\,C_{i j m n} C_{i k p q} \nabla_{m}\left(\nabla_{j}{C_{n k p q}}\right)+\frac{1}{2}\,C_{i j m n} \nabla_{i}{C_{m k p q}} \nabla_{n}{C_{j k p q}} - \frac{1}{2}\,C_{i j m n} \nabla_{i}{C_{j k p q}} \nabla_{m}{C_{n k p q}}+\frac{1}{2}\,C_{i j m n} C_{i k p q} \nabla_{j}\left(\nabla_{m}{C_{n k p q}}\right)+\frac{1}{2}\,C_{i j m n} C_{i k m p} \nabla_{q}\left(\nabla_{q}{C_{j k n p}}\right)+C_{i j m n} \nabla_{q}{C_{i k m p}} \nabla_{q}{C_{j k n p}} - \frac{1}{4}\,C_{i j m n} C_{i j k p} \nabla_{q}\left(\nabla_{q}{C_{m n k p}}\right) - \frac{1}{2}\,C_{i j m n} \nabla_{q}{C_{i j k p}} \nabla_{q}{C_{m n k p}}$

# %%
young_project_product(_);
# Out:
# ${}0\,$
