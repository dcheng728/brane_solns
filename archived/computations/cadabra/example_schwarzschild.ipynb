# %%
__cdbkernel__.display_fractions=True
{r,t,\phi,\theta}::Coordinate;
{\mu,\nu,\rho,\sigma,\lambda,\kappa,\chi,\gamma}::Indices(values={t,r,\phi,\theta}, position=fixed);
\partial{#}::PartialDerivative;
g_{\mu\nu}::Metric.
g^{\mu\nu}::InverseMetric.
# Out:
# ${}\text{Property Coordinate attached to}\left[r, t, \phi, \theta\right].$
# ${}\text{Property Indices(position=fixed, values=\{{t}
# , {r}
# , {\phi}
# , {\theta}
# \}) attached to}\left[\mu, \nu, \rho, \sigma, \lambda, \kappa, \chi, \gamma\right].$
# ${}\text{Property PartialDerivative attached to}\backslash\texttt{partial}\{\#\}.$

# %%
ss:= { g_{t t} = -(1-2 M/r),   
       g_{r r} = 1/(1-2 M/r), 
       g_{\theta\theta} = r**2, 
       g_{\phi\phi}=r**2 \sin(\theta)**2
     }.

complete(ss, $g^{\mu\nu}$);
# Out:
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.14/site-packages/cadabra2_jupyter/kernel.py", line 57, in do_execute
#     self._execute_python(pycode)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/opt/homebrew/lib/python3.14/site-packages/cadabra2_jupyter/kernel.py", line 111, in _execute_python
#     self._sandbox_context(pycode)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/opt/homebrew/lib/python3.14/site-packages/cadabra2_jupyter/context.py", line 52, in __call__
#     exec(code, self._sandbox)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 7, in <module>
# ModuleNotFoundError: No module named 'sympy'
